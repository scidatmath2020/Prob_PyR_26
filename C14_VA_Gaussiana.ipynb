# %% [markdown]
# ![imagenes](logo.png)

# %% [markdown]
# # Distribución Normal o Gaussiana
#
# ## $X \sim N(\mu, \sigma^2)$  o  $X \sim \mathcal{N}(\mu, \sigma^2)$
#
# ### Problemas que resuelve
#
# 1. Modelar fenómenos donde los valores se concentran alrededor de un valor central
#    con desviaciones simétricas.
#
# 2. Modelar errores aleatorios en mediciones y procesos de fabricación.
#
# 3. Modelar características físicas y biológicas (estaturas, pesos, coeficientes
#    intelectuales, etc.).
#
# 4. Base para muchos métodos estadísticos (pruebas de hipótesis, intervalos de
#    confianza, regresión, etc.).
#
# ### Definición
#
# Decimos que una variable aleatoria continua $X$ sigue una distribución Normal
# (o Gaussiana) con parámetros $\mu$ y $\sigma^2$ si su función de densidad de
# probabilidad (fdp) es:
#
# $$f(x) = \frac{1}{\sigma \sqrt{2\pi}} \exp\left(-\frac{(x-\mu)^2}{2\sigma^2}\right), \quad -\infty < x < \infty$$
#
# donde:
# - $\mu$ es la media (centro de la distribución)
# - $\sigma$ es la desviación típica (dispersión)
# - $\sigma^2$ es la varianza
# - $\mu \in \mathbb{R}$, $\sigma > 0$
#
# **Nota:** La densidad tiene soporte en toda la recta real ($-\infty, \infty$).

# %% [markdown]
# ## Parámetros y Significado
#
# - $\mu$ (media):
#   - Centro de la distribución (punto de máxima densidad)
#   - Mediana y moda coinciden con $\mu$
#   - Desplaza la campana horizontalmente
#   - $\mu \in \mathbb{R}$
#
# - $\sigma$ (desviación típica):
#   - Mide la dispersión alrededor de la media
#   - A mayor $\sigma$, más aplanada y ancha la campana
#   - A menor $\sigma$, más apuntada y estrecha la campana
#   - $\sigma > 0$
#
# - $\sigma^2$ (varianza):
#   - Cuadrado de la desviación típica
#   - $\sigma^2 > 0$
#
# **Forma de la fdp:** Campana de Gauss simétrica alrededor de $\mu$.
#
# **Características clave:**
# 1. **Simetría:** $f(\mu + x) = f(\mu - x)$
# 2. **Máximo en $x = \mu$:** $f(\mu) = \frac{1}{\sigma \sqrt{2\pi}}$
# 3. **Puntos de inflexión:** En $x = \mu \pm \sigma$
# 4. **Asintótica:** $f(x) \to 0$ cuando $x \to \pm\infty$
# 5. **Regla empírica (aproximada):**
#    - 68% de los datos en $\mu \pm \sigma$
#    - 95% de los datos en $\mu \pm 2\sigma$
#    - 99.7% de los datos en $\mu \pm 3\sigma$
#
# **Distribución Normal Estándar:** $Z \sim N(0, 1)$
# - $\mu = 0$, $\sigma = 1$
# - Densidad: $\phi(z) = \frac{1}{\sqrt{2\pi}} e^{-z^2/2}$
# - Función de distribución: $\Phi(z)$
# - Tablas y software usualmente trabajan con $Z$
#
# **Estandarización (tipificación):**
# $$Z = \frac{X - \mu}{\sigma} \sim N(0, 1)$$
#
# **Estandarización inversa:**
# $$X = \mu + \sigma Z \sim N(\mu, \sigma^2)$$

# %% [markdown]
# ## Propiedades principales
#
# - Función de densidad: $$f(x) = \frac{1}{\sigma \sqrt{2\pi}} \exp\left(-\frac{(x-\mu)^2}{2\sigma^2}\right), \quad -\infty < x < \infty$$
#
# - Función de distribución (FDA): $$F(x) = \Phi\left(\frac{x-\mu}{\sigma}\right)$$
#   donde $\Phi$ es la FDA de la Normal estándar.
#
# - Esperanza (Valor esperado): $$E[X] = \mu$$
#
# - Varianza: $$\text{Var}(X) = \sigma^2$$
#
# - Desviación estándar: $$\sigma$$
#
# **Percentiles notables:**
# - Q1 = $\mu - 0.6745\sigma$
# - Q2 = $\mu$ (mediana)
# - Q3 = $\mu + 0.6745\sigma$
# - IQR = $1.349\sigma$
# - Percentil 95 = $\mu + 1.645\sigma$
# - Percentil 97.5 = $\mu + 1.96\sigma$
# - Percentil 99 = $\mu + 2.326\sigma$

# %% [markdown]
# ## Tabla de Funciones
#
# | Explicación                    | R (stats)                          | Python (scipy)                |
# |--------------------------------|------------------------------------|-------------------------------|
# | Densidad f(x)                  | `dnorm(x, mean=mu, sd=sigma)`      | `norm.pdf(x, mu, sigma)`      |
# | Distribución acumulada F(x)    | `pnorm(x, mean=mu, sd=sigma)`      | `norm.cdf(x, mu, sigma)`      |
# | Cuantil (percentil inverso)    | `qnorm(p, mean=mu, sd=sigma)`      | `norm.ppf(p, mu, sigma)`      |
# | Generador de números aleatorios| `rnorm(n_sim, mean=mu, sd=sigma)`  | `norm.rvs(mu, sigma, size=n_sim)` |
#
# **Donde:**
# - `x` = valor a evaluar
# - `mu` = media de la distribución
# - `sigma` = desviación típica
# - `p` = probabilidad (entre 0 y 1) para el cuantil
# - `n_sim` = número de simulaciones a generar
#
# **¡IMPORTANTE!** Tanto en R como en Python, los parámetros son:
# - `mean = mu` (media)
# - `sd = sigma` (desviación típica)
# - **NO** se usa la varianza directamente, sino la desviación típica

# %% [markdown]
# ## Propiedades Adicionales
#
# ### Simetría y propiedades de la Normal estándar
# - **Simetría:** $\phi(-z) = \phi(z)$
# - **FDA:** $\Phi(-z) = 1 - \Phi(z)$
# - **Relación con errores:** $\Phi(z) + \Phi(-z) = 1$
#
# ### Cerradura bajo transformaciones lineales
# Si $X \sim N(\mu, \sigma^2)$, entonces para cualquier $a, b \in \mathbb{R}$:
# $$Y = aX + b \sim N(a\mu + b, a^2\sigma^2)$$
#
# ### Suma de Normales independientes
# Si $X_i \sim N(\mu_i, \sigma_i^2)$ son independientes, entonces:
# $$\sum_{i=1}^n X_i \sim N\left(\sum_{i=1}^n \mu_i, \sum_{i=1}^n \sigma_i^2\right)$$
#
# ### Distribuciones relacionadas
#
# **Normal Estándar → Chi-cuadrado:**
# Si $Z_1, ..., Z_n \sim N(0,1)$ i.i.d., entonces:
# $$\sum_{i=1}^n Z_i^2 \sim \chi^2_{(n)}$$
#
# **Normal → Log-Normal:**
# Si $X \sim N(\mu, \sigma^2)$, entonces:
# $$Y = e^X \sim \text{LogNormal}(\mu, \sigma^2)$$
#
# **Normal → Normal multivariante:**
# Generalización a $p$ dimensiones con vector de medias y matriz de covarianzas.

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 (Básico)**
# Las puntuaciones de CI (coeficiente intelectual) siguen una distribución Normal
# con media 100 y desviación típica 15.
#
# - Define la variable aleatoria X y sus parámetros.
# - ¿Cuál es la probabilidad de que una persona tenga CI entre 85 y 115?
# - ¿Cuál es la probabilidad de que una persona tenga CI mayor a 130?
# - ¿Qué CI deja por debajo al 90% de la población?
#
# **Ejercicio 2 (Esperanza y varianza)**
# El peso de los paquetes de café en una fábrica sigue una distribución Normal
# con media 500 g y desviación típica 8 g.
#
# - Define la variable aleatoria X y sus parámetros.
# - Calcula la esperanza y la varianza.
# - ¿Cuál es la probabilidad de que un paquete pese menos de 490 g?
# - ¿Entre qué pesos se encuentra el 95% central de los paquetes?
#
# **Ejercicio 3 (Simulación en Python)**
# Simula 10,000 valores de una distribución Normal con μ = 50 y σ = 5.
#
# - Calcula la proporción de simulaciones con valores entre 45 y 55.
# - Compara con la probabilidad teórica.
# - Calcula la media y varianza de la simulación y compáralas con los valores teóricos.
# - Grafica un histograma de frecuencias relativas y superpone la densidad teórica.
#
# **Ejercicio 4 (Estandarización)**
# Las calificaciones de un examen siguen una distribución Normal con media 65 y
# desviación típica 12.
#
# - Estandariza la variable X a Z ~ N(0,1).
# - Calcula P(X > 80) usando la estandarización.
# - Calcula P(55 < X < 75) usando la estandarización.
# - Si un estudiante obtuvo 72, ¿cuál es su puntuación Z y qué percentil ocupa?
#
# **Ejercicio 5 (Comparación con otras distribuciones)**
# Compara la distribución Normal con la Uniforme Continua y la Exponencial:
#
# - ¿En qué se diferencian en cuanto a forma y soporte?
# - ¿Qué distribución es simétrica? ¿Cuáles son asimétricas?
# - ¿Cuándo usarías cada una?
#
# **Ejercicio 6 (Propiedades de la Normal)**
# Sea X ~ N(μ, σ²).
#
# - Demuestra que la función de densidad es simétrica alrededor de μ.
# - Demuestra que E[X] = μ.
# - Si Y = aX + b, ¿cuál es la distribución de Y?
#
# **Ejercicio 7 (Simulación avanzada)**
# Genera 5000 muestras de una Normal con μ = 10 y σ = 2.
#
# - Calcula la media muestral y la varianza muestral.
# - Compara con los valores teóricos.
# - Calcula el porcentaje de valores que caen en los intervalos μ ± σ, μ ± 2σ y μ ± 3σ.
# - Compara con la regla empírica.
# - Grafica el histograma con la curva teórica superpuesta.

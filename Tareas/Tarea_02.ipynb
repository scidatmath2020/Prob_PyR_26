# %% [markdown]
# ![imagenes](logo.png)

# %% [markdown]
# # Tarea 02 Cálculo de Probabilidades con R y Python

# %% [markdown]
# 1. Dados ``a = 17`` y ``b = 5``, calcula
#
# - Suma, resta, multiplicación y división
# - Potencia de a elevado a 3
# - Módulo (residuo) de la división
#
# 2. Usando los operadores relacionales, evalúa y explica los siguientes resultados:
#
# - ¿17 > 5?
# - ¿17 == 5?
# - ¿17 != 5?
# - ¿17 >= 17?
#
# 3. Crea un vector llamado lanzamientos con los siguientes 15 resultados de un dado: [3, 1, 6, 2, 5, 4, 6, 1, 3, 5, 2, 6, 4, 1, 5]
#
# - Imprime el vector completo y su longitud
# - Calcula el promedio
# - Calcula el valor máximo y mínimo
# - ¿Cuál es el primer resultado?
# - ¿Cuál es el último resultado?
# - ¿Cuál es el resultado en la posición 7?
# - Extrae los primeros 5 lanzamientos
# - Extrae los últimos 4 lanzamientos
# - Extrae los elementos de la posición 4 a la 9 (incluyendo ambos extremos donde corresponda según el lenguaje)
# - ¿Cuántas veces salió el número 6?
# - ¿Cuántos fueron los lanzamientos que resultaron mayores o iguales a 5?
# - ¿Qué proporción de lanzamientos fueron números impares? (muestra el cálculo)

# %%
library("tidyverse")
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.2.1     ✔ readr     2.2.0
# ✔ forcats   1.0.1     ✔ stringr   1.6.0
# ✔ ggplot2   4.0.3     ✔ tibble    3.3.1
# ✔ lubridate 1.9.5     ✔ tidyr     1.3.2
# ✔ purrr     1.2.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
install.packages("tidyverse")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(tidyverse)

# %%
 mi_primer_vector =  c(2,7,2,1,9,10,-1)

# %%
round(mean(mi_primer_vector),2)
# Out:
# [1] 4.29

# %%
max(mi_primer_vector)
# Out:
# [1] 10

# %%
mi_primer_vector
# Out:
# [1]  2  7  2  1  9 10 -1

# %%
calificaciones = c(7.5, 9.0, 6.5, 8.5, 10.0, 5.5, 8.0, 9.5)
calificaciones
# Out:
# [1]  7.5  9.0  6.5  8.5 10.0  5.5  8.0  9.5

# %%
length(calificaciones)
# Out:
# [1] 8

# %%
calificaciones[1]
# Out:
# [1] 7.5

# %%
calificaciones[3]
# Out:
# [1] 6.5

# %%
### Quiero lo que hay en el último lugar del vector
calificaciones[-length(calificaciones)]
# Out:
# [1]  7.5  9.0  6.5  8.5 10.0  5.5  8.0

# %%
calificaciones[-1]
# Out:
# [1]  9.0  6.5  8.5 10.0  5.5  8.0  9.5

# %%
3:10
# Out:
# [1]  3  4  5  6  7  8  9 10

# %%
2026:2030
# Out:
# [1] 2026 2027 2028 2029 2030

# %%
calificaciones
# Out:
# [1]  7.5  9.0  6.5  8.5 10.0  5.5  8.0  9.5

# %%
calificaciones[2:4]
# Out:
# [1] 9.0 6.5 8.5

# %%
calificaciones[-(2:4)]
# Out:
# [1]  7.5 10.0  5.5  8.0  9.5

# %%
calificaciones[c(2,3,5,7)]
# Out:
# [1]  9.0  6.5 10.0  8.0

# %%
calificaciones
# Out:
# [1]  7.5  9.0  6.5  8.5 10.0  5.5  8.0  9.5

# %%
calificaciones > 7
# Out:
# [1]  TRUE  TRUE FALSE  TRUE  TRUE FALSE  TRUE  TRUE

# %%
calificaciones[calificaciones > 7 ]
# Out:
# [1]  7.5  9.0  8.5 10.0  8.0  9.5

# %%
!FALSE
# Out:
# [1] TRUE

# %%
calificaciones[!(calificaciones > 7)]
# Out:
# [1] 6.5 5.5

# %%
promedio = mean(calificaciones)
calificaciones[calificaciones <= promedio]
# Out:
# [1] 7.5 6.5 5.5 8.0

# %%
# Tiro un dado 10 veces y obtengo como resultados: 5, 6, 3, 2,6, 4, 1, 4, 5, 4
#  Cuántas veces se obtuvo un múltiplo de 3?

lanzamientos = c(5, 6, 3, 2,6, 4, 1, 4, 5, 4)
lanzamientos
# Out:
#  [1] 5 6 3 2 6 4 1 4 5 4

# %%
## El "o" (disyunción) en R es con |
## El "y" (conjunción) en R es con &
length(lanzamientos[lanzamientos == 3 | lanzamientos == 6])
# Out:
# [1] 3

# %%
length(lanzamientos[lanzamientos %% 3 == 0])
# Out:
# [1] 3

# %%
sum(lanzamientos %% 3 == 0)
# Out:
# [1] 3

# %%
M = matrix(c(1,2,3,4,5,6,7,8,9,2025,2026,2030), nrow = 3,byrow = TRUE)
M
# Out:
#      [,1] [,2] [,3] [,4]
# [1,] 1       2    3    4
# [2,] 5       6    7    8
# [3,] 9    2025 2026 2030

# %%
dim(M)
# Out:
# [1] 3 4

# %%
dim(M)[2]
# Out:
# [1] 4

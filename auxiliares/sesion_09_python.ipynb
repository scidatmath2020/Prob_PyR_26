# %%
import math

# %%
math.factorial(3)
# Out:
# 6

# %%
math.factorial(10)
# Out:
# 3628800

# %%
math.factorial(11)
# Out:
# 39916800

# %%
n = 8
k = 3

math.factorial(n) / math.factorial(n - k)
# Out:
# 336.0

# %%
6*7*8
# Out:
# 336

# %%
math.factorial(8)
# Out:
# 40320

# %%
2*math.factorial(7)
# Out:
# 10080

# %%
math.comb(10,3)
# Out:
# 120

# %%
factorial(3)
# Out:
# [1] 6

# %%
factorial(5)
# Out:
# [1] 120

# %%
factorial(10)
# Out:
# [1] 3628800

# %%
factorial(11)
# Out:
# [1] 39916800

# %%
n = 8
k = 3

factorial(n) / factorial(n - k)
# Out:
# [1] 336

# %%
choose(10,3)
# Out:
# [1] 120

# %%
factorial(10) / (factorial(3)*factorial(7))
# Out:
# [1] 120

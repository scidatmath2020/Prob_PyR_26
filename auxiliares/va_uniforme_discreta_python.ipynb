# %%
import numpy as np

# %%
a = 3
b = 6
n = 3420

np.random.seed(2026)
lanzamientos = np.random.choice(np.arange(a, b + 1), size=n, replace=True)

# %%
lanzamientos.mean()
# Out:
# np.float64(4.494736842105263)

# %%
lanzamientos.var()
# Out:
# np.float64(1.2581594336718989)

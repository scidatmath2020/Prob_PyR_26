# %%
a = 3
b = 6
n = 3420

set.seed(2026)
lanzamientos = sample(a:b, n, replace=TRUE)

# %%
# Frecuencias
table(lanzamientos)
# Out:
# lanzamientos
#   3   4   5   6
# 893 840 839 848

# %%
# Proporciones
n/(b-a+1)
# Out:
# [1] 855

# %%
# Media
mean(lanzamientos)
# Out:
# [1] 4.480117

# %%
# Varianza
var(lanzamientos)
# Out:
# [1] 1.268104
